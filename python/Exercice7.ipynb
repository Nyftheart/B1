# %%
M = [1,2,8,6,9,8]
NbPair = 0
i = 0
while i < len(M):
  if M[i]%2==0:
    NbPair = NbPair + 1
  i = i + 1
print (NbPair)
# Out:
# 4

# %%
N = [0,0,0,0,2,1,2,0,2,0]

i=0
while i < len(N):
  if N[i] == 0:
    del N[i]
  else:
    i = i + 1

print(N)
# Out:
# [2, 1, 2, 2]

# %%
T1 = [1,7,6,4]
T2 = [5,9,3,2]
T3 = [] 

i=0
while i < len(T1):
  s = T1[i] + T2[i]
  T3.append(s)
  i=i+1

print(T3)

# %%
L = [2,4,12,3,123,2,2,45]

max = L[0]
i = 0
while i< len(L):
  if L[i]>max:
    max = L[i]
  i=i+1
print(max)

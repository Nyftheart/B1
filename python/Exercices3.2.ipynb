# %%
mystere = 25
reponse = int(input())
while mystere != reponse :
  if reponse > mystere:
    print("Trop haut")
  else : 
    print("Trop bas")
  reponse = int(input())

print("Victoire")

# %%
a = 1
b = 1
compteur = 2
while compteur < 20:
  s = a + b
  a = b
  b = s
  compteur = compteur + 1
  
print(b)
# Out:
# 6765

# %%
i = 0
while i<10:
  j=0
  while j<10:
    k=0
    while k<10:
      if i*i*i+j*j*j+k*k*k == i*100+j*10+k :
        print(i*100+j*10+k)
      k=k+1
    j=j+1
  i=i+1
# Out:
# 0
# 1
# 153
# 370
# 371
# 407

# %%
compteur = 0
while compteur <= 40:
  if compteur%2 == 0 :
    print(compteur)
  compteur = compteur + 1

# %%
a = 3
b = 6
compteur = 0
resultat = 1
while compteur < b:
  resultat = resultat * a
  compteur=compteur +1
print(resultat)
# Out:
# 729

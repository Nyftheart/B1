# %%
age = int (input())
if age >=18:
  print("Majeur")
else : 
  print("Mineur")
# Out:
# 5
# Mineur

# %%
a = int(input())
b = int(input())
if a > b :
  print(b)
else :
  print(a)

# %%
a = int(input())
b = int(input())
c = int(input())
if a < b and a < c :
  print (a)
elif b < c:
  print (b)
else:
  print (c)
# Out:
# 2
# 3
# 6
# 2

# %%
note = int(input())

if note > 20 or note < 0:
  print ("error")
elif note >= 18 :
  print ("Felicitations")
elif note >= 16 :
  print ("Très bien")
elif note >= 14 :
  print ("Bien")
elif note >= 12 :
  print ("Assez bien")
elif note >= 10 :
  print ("Passable")
else : 
  print ("Echec")

# %% [markdown]
# https://discord.gg/dq9ARmR

# %%
annee = int(input())
if (annee%4 == 0 and annee%100 != 0) or annee%400==0:
  print("bissextile")

# %%
choco = int(input())
if choco < 200:
  print("error")
else : 
  NbGateau = int(choco / 200)
  ChocoRestant = choco % 200
  print ("Vous pouvez faire ",NbGateau, "gateaux")
  print(NbGateau)
# Out:
# 500
# Vous pouvez faire  2 gateaux

# %%
compteur = 0
while compteur < 1000:
  print(compteur,"coucou")
  compteur = compteur + 1
  if compteur %2 ==0:
    print('COUCOU')
# Out:
# 0 coucou
# 1 coucou
# COUCOU
# 2 coucou
# 3 coucou
# COUCOU
# 4 coucou
# 5 coucou
# COUCOU
# 6 coucou
# 7 coucou
# COUCOU
# 8 coucou
# 9 coucou
# COUCOU
# 10 coucou
# 11 coucou
# COUCOU
# 12 coucou
# 13 coucou
# COUCOU
# 14 coucou
# 15 coucou
# COUCOU
# 16 coucou
# 17 coucou
# COUCOU
# 18 coucou
# 19 coucou
# COUCOU
# 20 coucou
# 21 coucou
# COUCOU
# 22 coucou
# 23 coucou
# COUCOU
# 24 coucou
# 25 coucou
# COUCOU
# 26 coucou
# 27 coucou
# COUCOU
# 28 coucou
# 29 coucou
# COUCOU
# 30 coucou
# 31 coucou
# COUCOU
# 32 coucou
# 33 coucou
# COUCOU
# 34 coucou
# 35 coucou
# COUCOU
# 36 coucou
# 37 coucou
# COUCOU
# 38 coucou
# 39 coucou
# COUCOU
# 40 coucou
# 41 coucou
# COUCOU
# 42 coucou
# 43 coucou
# COUCOU
# 44 coucou
# 45 coucou
# COUCOU
# 46 coucou
# 47 coucou
# COUCOU
# 48 coucou
# 49 coucou
# COUCOU
# 50 coucou
# 51 coucou
# COUCOU
# 52 coucou
# 53 coucou
# COUCOU
# 54 coucou
# 55 coucou
# COUCOU
# 56 coucou
# 57 coucou
# COUCOU
# 58 coucou
# 59 coucou
# COUCOU
# 60 coucou
# ...

# %%
c = int(input())
carre = c * c
print (carre)
# Out:
# 10
# 100

# %%
a = int(input())
b = int(input())
print (a , " - " , b)
c = a
a = b
b = c
print (a , " - " , b)
# Out:
# 2
# 3
# 2  -  3
# 3  -  2

# %%
r = int(input()) # On demande à l'utilisateur un chiffre
p = 2 * 3.14 * r # Calcul du périmètre
print (p)        # Affichage du résultat
# Out:
# 2
# 12.56

# %%
n1 = int (input())
n2 = int (input())
n3 = int (input())
n4 = int (input())

Moyenne = (n1+n2+n3+n4)/4

print (Moyenne)
# Out:
# 1
# 2
# 3
# 4
# 2.5

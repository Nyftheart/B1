# %%
compteur = 100
while compteur > 0:
  print(compteur)
  compteur = compteur -1

# %%
compteur = 0
somme = 0
while compteur <=10 :
  compteur = compteur + 1
  somme = somme + compteur
print (somme)
# Out:
# 66

# %%
compteur = 0
SommeNote =0
while compteur<10:
  note = int(input())
  SommeNote = SommeNote + note
  compteur = compteur + 1
Moyenne = SommeNote/10
print (Moyenne)

# %%
Nb = int(input())
compteur = 0
while compteur <10 :
  resultat = Nb * compteur 
  print(Nb,"x",compteur,"=",resultat)
  compteur = compteur + 1
# Out:
# 5
# 5 x 0 = 0
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45

# %%
limite = int(input())
compteur = 1
fact = 1
while compteur <= limite:
  fact = fact * compteur 
  compteur = compteur + 1
print(fact)

# %%
ChiffreMystere = 112
reponse = int(input())
while reponse != ChiffreMystere:
  if reponse > ChiffreMystere:
    print ("trop haut")
  else :
    print ("trop bas")
  reponse = int(input)
print("victoire")

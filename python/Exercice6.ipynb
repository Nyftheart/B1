# %%
Li = [1,5,7,9,5]

for ChaqueValeurDeLi in Li:
  print (ChaqueValeurDeLi)
  
i = 0
while i < len(Li):
  if i !=0:
    print(Li[i])
  i = i + 1

# %%
from random import *

Etudiants = []
i = 0 
while i < 500:
  r = randrange(0,21)
  Etudiants.append(r)
  i = i + 1
  
i = 0
while i< len(Etudiants):
  print(Etudiants[i])
  i=i+1

# %%
Zero = []
i = 0
while i < 50:
  Zero.append(0)
  i = i + 1

i = 0
while i < len(Zero):
  print(Zero[i])
  i = i + 1

# %%
Indice = []
i = 0
while i < 20:
  Indice.append(i)
  i = i + 1
  
i = 0
while i < len(Indice):
  print(Indice[i])
  i = i + 1

# %%
Liste = [123,'a',2.2]
print(Liste[0])
print(Liste[1])
print(Liste[2])

Liste.append("coucou")

print(Liste[3])

del Liste[0]
print(Liste[0])

# %%
from random import *

Liste2 = [] 
i = 0
while i < 1600:
  r = randrange(0,20)
  Liste2.append(r)
  i=i+1

i=0
while i<len(Liste2):
  print(Liste2[i])
  i=i+1

# %%
from random import *
Etudiants = []
i = 0 
NbEtudiants = 10
while i < NbEtudiants:
  r = randrange(0,21)
  Etudiants.append(r)
  i = i + 1
  
i = 0
somme = 0
while i < len(Etudiants):
  somme = somme + Etudiants[i]
  i=i+1
Moyenne = somme/len(Etudiants)
print(Moyenne)
# Out:
# 10.00808

# %%
l1 = [1,2,3]
l2 = [4,5,6,7]
l3 = l1
i = 0
while i < len(l2):
  l3.append(l2[i])
  i=i+1
i = 0
while i < len(l3):
  print(l3[i])
  i = i + 1

# %%
Liste = [1,2,3]

a = len(Liste)

print(a)
# Out:
# 3

# %%
def FirstValue(L):
  r = L[0]
  return r

LI = [1,2,3]
a = FirstValue(LI)
print(a)
# Out:
# 1

# %%
def CreationListe(taille):
  l = []
  i = 0
  while i<taille:
    l.append(0)
    i=i+1
  return l

Lzero = CreationListe()
